# %% [markdown]
# # Evaluation
#
# Run task evaluations for the base model and matching LoRA checkpoints.

# %%
from pathlib import Path
from theoretical.evaluation.analysis import run

# Configuration
model_id = "LiquidAI/LFM2.5-1.2B-Thinking"
lora_repository = "Heroi/multitune-lora-backup"
output_path = Path("theoretical/evaluation/data/evaluation_results.csv")

# %%
result_path = run(output_path=output_path, model_id=model_id, lora_repository=lora_repository)
result_path
