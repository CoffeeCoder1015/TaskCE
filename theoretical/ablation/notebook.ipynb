# %% [markdown]
# # Ablation
#
# Select neurons from saved compositional results, rerun the model, and persist cumulative measurements.

# %%
from pathlib import Path
from theoretical.ablation.analysis import run

# Configuration
task_name = "snli"
output_directory = Path("theoretical/ablation/data")
model_id = "LiquidAI/LFM2.5-1.2B-Thinking"
lora_repository = "Heroi/multitune-lora-backup"
layer = "model.layers.8.feed_forward"

# %%
results = run(task_name, output_directory=output_directory, model_id=model_id, lora_repository=lora_repository, layer=layer)
results
